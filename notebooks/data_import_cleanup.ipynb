# %%
import yfinance as yf
import pandas as pd
import datetime

tickers = ["ZW=F","WEAT",
    # Sector Proxies
    "MOO", "VEGI", "DBA", "CORN",
    # Individual Universe (Mandatory G13 + Correlated)
    "ADM", "BG", "CTVA", "NTR", "DE", "MOS", "CF", "FMC", "AGCO", 
    "CNH", "ANDE", "INGR", "IPI", "UAN", "LXU", "TSCO", "DAR"
    ]

end_date = datetime.date.today()
start_date = end_date - datetime.timedelta(8*365)

raw_data = yf.download(tickers,start=start_date,end=end_date,group_by=tickers)

price_data = pd.DataFrame()


# Handle Missing Data (Crucial for Gurobi / Cointegration)
# Forward fill first (carry previous day's price forward on holidays)
cleaned_data = raw_data.ffill()  # Forward fill
cleaned_data = cleaned_data.bfill()  # Backward fill

# 5. Export the Dataset
cleaned_data.to_csv("C:/Users/mb223851/Documents/Projets A4/commodities_markets_models/data/processed")
print(f"Data successfully cleaned and saved to {output_path}")
print(f"Dataset shape: {cleaned_data.shape[0]} days, {cleaned_data.shape[1]} assets.")
# Out:
# [*********************100%***********************]  23 of 23 completed
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[19], line 27
#      24 cleaned_data = cleaned_data.bfill()  # Backward fill
#      26 # 5. Export the Dataset
# ---> 27 cleaned_data.to_csv("C:/Users/mb223851/Documents/Projets A4/commodities_markets_models/data/processed")
#      28 print(f"Data successfully cleaned and saved to {output_path}")
#      29 print(f"Dataset shape: {cleaned_data.shape[0]} days, {cleaned_data.shape[1]} assets.")
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
# ...
